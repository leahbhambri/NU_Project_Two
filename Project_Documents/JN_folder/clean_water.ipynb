# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
from datetime import datetime
from sqlalchemy import create_engine
from sqlalchemy import Table, Column, Integer, String, Float, MetaData
import json
from config import password

# %%
# pull in percent of safe water csv
safe_water_file = "data/percent_safe_water.csv"
safe_water_df = pd.read_csv(safe_water_file)
safe_water_df
# Out:
#      Country Name Country Code  \
# 0           Aruba          ABW
# 1     Afghanistan          AFG
# 2          Angola          AGO
# 3         Albania          ALB
# 4         Andorra          AND
# ..            ...          ...
# 259        Kosovo          XKX
# 260   Yemen, Rep.          YEM
# 261  South Africa          ZAF
# 262        Zambia          ZMB
# 263      Zimbabwe          ZWE
#
#                                         Indicator Name  Indicator Code  1960  \
# 0    People using safely managed drinking water ser...  SH.H2O.SMDW.ZS   NaN
# 1    People using safely managed drinking water ser...  SH.H2O.SMDW.ZS   NaN
# 2    People using safely managed drinking water ser...  SH.H2O.SMDW.ZS   NaN
# 3    People using safely managed drinking water ser...  SH.H2O.SMDW.ZS   NaN
# 4    People using safely managed drinking water ser...  SH.H2O.SMDW.ZS   NaN
# ..                                                 ...             ...   ...
# 259  People using safely managed drinking water ser...  SH.H2O.SMDW.ZS   NaN
# 260  People using safely managed drinking water ser...  SH.H2O.SMDW.ZS   NaN
# 261  People using safely managed drinking water ser...  SH.H2O.SMDW.ZS   NaN
# 262  People using safely managed drinking water ser...  SH.H2O.SMDW.ZS   NaN
# 263  People using safely managed drinking water ser...  SH.H2O.SMDW.ZS   NaN
#
#      1961  1962  1963  1964  1965  ...       2012       2013       2014  \
# 0     NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 1     NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 2     NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 3     NaN   NaN   NaN   NaN   NaN  ...  65.901394  67.893339  69.903702
# 4     NaN   NaN   NaN   NaN   NaN  ...  90.640001  90.640000  90.639998
# ..    ...   ...   ...   ...   ...  ...        ...        ...        ...
# 259   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 260   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 261   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 262   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 263   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
#
#           2015       2016       2017  2018  2019  2020  Unnamed: 65
# 0          NaN        NaN        NaN   NaN   NaN   NaN          NaN
# 1          NaN        NaN        NaN   NaN   NaN   NaN          NaN
# 2          NaN        NaN        NaN   NaN   NaN   NaN          NaN
# 3    69.944500  69.984329  70.023150   NaN   NaN   NaN          NaN
# 4    90.640002  90.640000  90.639997   NaN   NaN   NaN          NaN
# ..         ...        ...        ...   ...   ...   ...          ...
# 259        NaN        NaN        NaN   NaN   NaN   NaN          NaN
# 260        NaN        NaN        NaN   NaN   NaN   NaN          NaN
# 261        NaN        NaN        NaN   NaN   NaN   NaN          NaN
# 262        NaN        NaN        NaN   NaN   NaN   NaN          NaN
# 263        NaN        NaN        NaN   NaN   NaN   NaN          NaN
#
# [264 rows x 66 columns]

# %%
#select columns for analysis
safe_water_df = safe_water_df[['Country Name', 'Country Code','2017']]
safe_water_df
# Out:
#      Country Name Country Code       2017
# 0           Aruba          ABW        NaN
# 1     Afghanistan          AFG        NaN
# 2          Angola          AGO        NaN
# 3         Albania          ALB  70.023150
# 4         Andorra          AND  90.639997
# ..            ...          ...        ...
# 259        Kosovo          XKX        NaN
# 260   Yemen, Rep.          YEM        NaN
# 261  South Africa          ZAF        NaN
# 262        Zambia          ZMB        NaN
# 263      Zimbabwe          ZWE        NaN
#
# [264 rows x 3 columns]

# %%
#convert strings to lower case for PG Admin connection
safe_water_df.columns = safe_water_df.columns.str.lower()
safe_water_df.columns = safe_water_df.columns.str.replace(' ','_')
safe_water_df
# Out:
#      country_name code  safe_water_2017
# 0           Aruba  ABW              NaN
# 1     Afghanistan  AFG              NaN
# 2          Angola  AGO              NaN
# 3         Albania  ALB        70.023150
# 4         Andorra  AND        90.639997
# ..            ...  ...              ...
# 259        Kosovo  XKX              NaN
# 260   Yemen, Rep.  YEM              NaN
# 261  South Africa  ZAF              NaN
# 262        Zambia  ZMB              NaN
# 263      Zimbabwe  ZWE              NaN
#
# [264 rows x 3 columns]

# %%
#rename columns 
safe_water_df = safe_water_df.rename(columns={'country_code': 'code', '2017':'safe_water_2017'})
safe_water_df
# Out:
#      country_name code  safe_water_2017
# 0           Aruba  ABW              NaN
# 1     Afghanistan  AFG              NaN
# 2          Angola  AGO              NaN
# 3         Albania  ALB        70.023150
# 4         Andorra  AND        90.639997
# ..            ...  ...              ...
# 259        Kosovo  XKX              NaN
# 260   Yemen, Rep.  YEM              NaN
# 261  South Africa  ZAF              NaN
# 262        Zambia  ZMB              NaN
# 263      Zimbabwe  ZWE              NaN
#
# [264 rows x 3 columns]

# %%
#drop NaN columns
safe_water_df = safe_water_df.dropna()
safe_water_df
# Out:
#        country_name code  safe_water_2017
# 3           Albania  ALB        70.023150
# 4           Andorra  AND        90.639997
# 8           Armenia  ARM        86.476355
# 9    American Samoa  ASM        12.575083
# 12          Austria  AUT        98.906201
# ..              ...  ...              ...
# 249   United States  USA        99.001778
# 250      Uzbekistan  UZB        58.903805
# 256         Vanuatu  VUT        44.130326
# 257           World  WLD        70.644880
# 258           Samoa  WSM        58.821106
#
# [126 rows x 3 columns]

# %%
#check data types (need to convert object to float)
safe_water_df.dtypes
# Out:
# country_name        object
# code                object
# safe_water_2017    float64
# dtype: object

# %%
# pull in death by risk factor
cause_of_death_file = "data/number_of_deaths_by_risk_factor.csv"
cod_df = pd.read_csv(cause_of_death_file)
cod_df
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6463     Zimbabwe  ZWE  2013
# 6464     Zimbabwe  ZWE  2014
# 6465     Zimbabwe  ZWE  2015
# 6466     Zimbabwe  ZWE  2016
# 6467     Zimbabwe  ZWE  2017
#
#       Deaths - Unsafe water source - Sex: Both - Age: All Ages (Number)  \
# 0                                           7554.049543
# 1                                           7359.676749
# 2                                           7650.437822
# 3                                          10270.731383
# 4                                          11409.177112
# ...                                                 ...
# 6463                                        4254.282075
# 6464                                        4098.769691
# 6465                                        3921.291358
# 6466                                        3802.257512
# 6467                                        3796.070615
#
#       Deaths - Unsafe sanitation - Sex: Both - Age: All Ages (Number)  \
# 0                                           5887.747628
# 1                                           5732.770160
# 2                                           5954.804987
# 3                                           7986.736613
# 4                                           8863.010065
# ...                                                 ...
# 6463                                        2977.649750
# 6464                                        2856.426187
# 6465                                        2717.735794
# 6466                                        2624.315858
# 6467                                        2612.122560
#
#       Deaths - No access to handwashing facility - Sex: Both - Age: All Ages (Number)  \
# 0                                           5412.314513
# 1                                           5287.891103
# 2                                           5506.657363
# 3                                           7104.620351
# 4                                           8051.515953
# ...                                                 ...
# 6463                                        3913.210510
# 6464                                        3809.245683
# 6465                                        3688.442102
# 6466                                        3603.179799
# 6467                                        3579.352078
#
#       Deaths - Household air pollution from solid fuels - Sex: Both - Age: All Ages (Number)  \
# 0                                          22388.497233
# 1                                          22128.758206
# 2                                          22873.768789
# 3                                          25599.756284
# 4                                          28013.167200
# ...                                                 ...
# 6463                                        7613.561005
# 6464                                        7429.446352
# 6465                                        7267.029297
# 6466                                        7134.595677
# 6467                                        6982.337249
#
#       Deaths - Non-exclusive breastfeeding - Sex: Both - Age: All Ages (Number)  \
# 0                                           3221.138842
# 1                                           3150.559597
# 2                                           3331.349048
# 3                                           4477.006100
# 4                                           5102.622054
# ...                                                 ...
# 6463                                        1037.968042
# 6464                                         972.886327
# 6465                                         912.248164
# 6466                                         875.706009
# 6467                                         866.902012
#
#       Deaths - Discontinued breastfeeding - Sex: Both - Age: All Ages (Number)  \
# 0                                            156.097553
# 1                                            151.539851
# 2                                            156.609194
# 3                                            206.834451
# 4                                            233.930571
# ...                                                 ...
# 6463                                          59.150493
# 6464                                          54.334796
# 6465                                          50.255551
# 6466                                          47.719473
# 6467                                          46.816760
#
#       Deaths - Child wasting - Sex: Both - Age: All Ages (Number)  ...  \
# 0                                          22778.849249            ...
# 1                                          22292.691113            ...
# 2                                          23102.197940            ...
# 3                                          27902.669960            ...
# 4                                          32929.005932            ...
# ...                                                 ...            ...
# 6463                                        7703.062474            ...
# 6464                                        7401.059382            ...
# 6465                                        7100.476546            ...
# 6466                                        6823.766727            ...
# 6467                                        6609.236886            ...
#
#       Deaths - Air pollution - Sex: Both - Age: All Ages (Number)  \
# 0                                          26598.006727
# 1                                          26379.532218
# 2                                          27263.127914
# 3                                          30495.561499
# 4                                          33323.161401
# ...                                                 ...
# 6463                                        9593.033931
# 6464                                        9387.193480
# 6465                                        9189.336702
# 6466                                        9092.577378
# 6467                                        9020.941349
#
#       Deaths – Outdoor air pollution (all ages) (IHME)  \
# 0                                              4383.83
# 1                                              4426.36
# 2                                              4568.91
# 3                                              5080.29
# 4                                              5499.23
# ...                                                ...
# 6463                                           2053.58
# 6464                                           2030.92
# 6465                                           1994.91
# 6466                                           2030.88
# 6467                                           2112.19
#
#       Deaths - Diet low in fiber - Sex: Both - Age: All Ages (Number)  \
# 0                                           2864.234512
# 1                                           2974.479775
# 2                                           3168.591633
# 3                                           3401.045056
# 4                                           3599.709735
# ...                                                 ...
# 6463                                         619.391594
# 6464                                         604.168238
# 6465                                         594.347147
# 6466                                         592.092457
# 6467                                         595.869132
#
#       Deaths - Diet high in sodium - Sex: Both - Age: All Ages (Number)  \
# 0                                           2737.197934
# 1                                           2741.184956
# 2                                           2798.560245
# 3                                           2853.301679
# 4                                           2880.025765
# ...                                                 ...
# 6463                                        1018.389001
# 6464                                        1016.407438
# 6465                                        1019.971539
# 6466                                        1032.181216
# 6467                                        1049.402363
#
#       Deaths - Diet low in legumes - Sex: Both - Age: All Ages (Number)  \
# 0                                           3418.965194
# 1                                           3457.398250
# 2                                           3586.490291
# 3                                           3746.266658
# 4                                           3869.288402
# ...                                                 ...
# 6463                                         469.787520
# 6464                                         482.800746
# 6465                                         494.337563
# 6466                                         507.088683
# 6467                                         520.751472
#
#       Deaths - Diet low in calcium - Sex: Both - Age: All Ages (Number)  \
# 0                                            181.287701
# 1                                            184.251584
# 2                                            191.318450
# 3                                            199.767293
# 4                                            206.619714
# ...                                                 ...
# 6463                                         182.630009
# 6464                                         184.379579
# 6465                                         188.020716
# 6466                                         192.913319
# 6467                                         196.849490
#
#       Deaths - Diet high in red meat - Sex: Both - Age: All Ages (Number)  \
# 0                                              0.220484
# 1                                              0.184714
# 2                                              0.151354
# 3                                              0.109392
# 4                                              0.059103
# ...                                                 ...
# 6463                                           0.000311
# 6464                                           0.000756
# 6465                                           0.001512
# 6466                                           0.002787
# 6467                                           0.004705
#
#       Deaths - Diet low in whole grains - Sex: Both - Age: All Ages (Number)  \
# 0                                          11381.377345
# 1                                          11487.832390
# 2                                          11866.235572
# 3                                          12335.961682
# 4                                          12672.950191
# ...                                                 ...
# 6463                                        2687.636261
# 6464                                        2654.381923
# 6465                                        2635.950107
# 6466                                        2641.376815
# 6467                                        2664.132572
#
#       Deaths - Diet low in nuts and seeds - Sex: Both - Age: All Ages (Number)  \
# 0                                           7299.867330
# 1                                           7386.764303
# 2                                           7640.628526
# 3                                           7968.311853
# 4                                           8244.368430
# ...                                                 ...
# 6463                                        2409.930182
# 6464                                        2399.261581
# 6465                                        2398.525219
# 6466                                        2417.422521
# 6467                                        2449.546229
#
#       Deaths - Diet low in seafood omega-3 fatty acids - Sex: Both - Age: All Ages (Number)
# 0                                           6456.565238
# 1                                           6511.344276
# 2                                           6703.095594
# 3                                           6946.196824
# 4                                           7138.030745
# ...                                                 ...
# 6463                                        1757.282549
# 6464                                        1740.938755
# 6465                                        1732.926445
# 6466                                        1740.653975
# 6467                                        1762.183897
#
# [6468 rows x 38 columns]

# %%
#select only year 2017 (most recent data)
cod_df = cod_df[cod_df.Year == 2017]
cod_df
# Out:
#                           Entity      Code  Year  \
# 27                   Afghanistan       AFG  2017
# 55                       Albania       ALB  2017
# 83                       Algeria       DZA  2017
# 111               American Samoa       ASM  2017
# 139         Andean Latin America       NaN  2017
# ...                          ...       ...   ...
# 6355  Western Sub-Saharan Africa       NaN  2017
# 6383                       World  OWID_WRL  2017
# 6411                       Yemen       YEM  2017
# 6439                      Zambia       ZMB  2017
# 6467                    Zimbabwe       ZWE  2017
#
#       Deaths - Unsafe water source - Sex: Both - Age: All Ages (Number)  \
# 27                                         5.256649e+03
# 55                                         4.091664e+00
# 83                                         1.899361e+02
# 111                                        7.200565e-01
# 139                                        1.257987e+03
# ...                                                 ...
# 6355                                       2.324944e+05
# 6383                                       1.232368e+06
# 6411                                       6.435590e+03
# 6439                                       6.288668e+03
# 6467                                       3.796071e+03
#
#       Deaths - Unsafe sanitation - Sex: Both - Age: All Ages (Number)  \
# 27                                          3783.111117
# 55                                             1.597907
# 83                                            58.910622
# 111                                            0.179205
# 139                                          733.649228
# ...                                                 ...
# 6355                                      160952.618364
# 6383                                      774240.986150
# 6411                                        4011.286680
# 6439                                        4718.900370
# 6467                                        2612.122560
#
#       Deaths - No access to handwashing facility - Sex: Both - Age: All Ages (Number)  \
# 27                                          4156.209013
# 55                                             4.501301
# 83                                           191.730462
# 111                                            0.293769
# 139                                         1578.129626
# ...                                                 ...
# 6355                                      169944.465538
# 6383                                      707247.712854
# 6411                                        3029.543803
# 6439                                        4553.893978
# 6467                                        3579.352078
#
#       Deaths - Household air pollution from solid fuels - Sex: Both - Age: All Ages (Number)  \
# 27                                         1.939738e+04
# 55                                         7.368815e+02
# 83                                         5.811236e+01
# 111                                        7.550280e+00
# 139                                        5.773893e+03
# ...                                                 ...
# 6355                                       1.721336e+05
# 6383                                       1.640600e+06
# 6411                                       4.700403e+03
# 6439                                       5.452029e+03
# 6467                                       6.982337e+03
#
#       Deaths - Non-exclusive breastfeeding - Sex: Both - Age: All Ages (Number)  \
# 27                                          2422.369175
# 55                                             8.173119
# 83                                           126.552097
# 111                                            0.118482
# 139                                          344.102079
# ...                                                 ...
# 6355                                       53606.767487
# 6383                                      160983.374426
# 6411                                        2440.200553
# 6439                                         752.156871
# 6467                                         866.902012
#
#       Deaths - Discontinued breastfeeding - Sex: Both - Age: All Ages (Number)  \
# 27                                            94.118135
# 55                                             0.071829
# 83                                             7.723609
# 111                                            0.003936
# 139                                           20.477721
# ...                                                 ...
# 6355                                        3448.963539
# 6383                                       10011.809235
# 6411                                         237.628511
# 6439                                          63.183108
# 6467                                          46.816760
#
#       Deaths - Child wasting - Sex: Both - Age: All Ages (Number)  ...  \
# 27                                         1.457527e+04            ...
# 55                                         4.061321e+01            ...
# 83                                         6.354547e+02            ...
# 111                                        2.285860e+00            ...
# 139                                        3.615349e+03            ...
# ...                                                 ...            ...
# 6355                                       3.461004e+05            ...
# 6383                                       1.077102e+06            ...
# 6411                                       9.475333e+03            ...
# 6439                                       7.289651e+03            ...
# 6467                                       6.609237e+03            ...
#
#       Deaths - Air pollution - Sex: Both - Age: All Ages (Number)  \
# 27                                         2.605420e+04
# 55                                         1.638571e+03
# 83                                         1.322228e+04
# 111                                        2.217993e+01
# 139                                        1.768615e+04
# ...                                                 ...
# 6355                                       2.536535e+05
# 6383                                       4.895476e+06
# 6411                                       1.237858e+04
# 6439                                       7.105757e+03
# 6467                                       9.020941e+03
#
#       Deaths – Outdoor air pollution (all ages) (IHME)  \
# 27                                             6872.06
# 55                                              919.59
# 83                                            13315.30
# 111                                              14.63
# 139                                           12011.09
# ...                                                ...
# 6355                                          82793.37
# 6383                                        3408877.62
# 6411                                           7777.21
# 6439                                           1726.75
# 6467                                           2112.19
#
#       Deaths - Diet low in fiber - Sex: Both - Age: All Ages (Number)  \
# 27                                          4889.502247
# 55                                           428.785803
# 83                                          3004.104009
# 111                                            2.679124
# 139                                         3337.535571
# ...                                                 ...
# 6355                                        6408.003926
# 6383                                      873407.776902
# 6411                                        3730.797892
# 6439                                         397.244094
# 6467                                         595.869132
#
#       Deaths - Diet high in sodium - Sex: Both - Age: All Ages (Number)  \
# 27                                         3.457084e+03
# 55                                         1.668336e+03
# 83                                         5.828760e+03
# 111                                        8.519993e+00
# 139                                        9.758082e+03
# ...                                                 ...
# 6355                                       2.474591e+04
# 6383                                       3.196514e+06
# 6411                                       3.271575e+03
# 6439                                       1.183670e+03
# 6467                                       1.049402e+03
#
#       Deaths - Diet low in legumes - Sex: Both - Age: All Ages (Number)  \
# 27                                          4384.887948
# 55                                           429.775831
# 83                                          2761.644707
# 111                                            4.836963
# 139                                         2169.986257
# ...                                                 ...
# 6355                                        3056.112541
# 6383                                      534767.131156
# 6411                                        2254.400766
# 6439                                          54.161681
# 6467                                         520.751472
#
#       Deaths - Diet low in calcium - Sex: Both - Age: All Ages (Number)  \
# 27                                           325.722066
# 55                                            23.218640
# 83                                           370.146859
# 111                                            1.089152
# 139                                         1033.264841
# ...                                                 ...
# 6355                                        3461.469135
# 6383                                      184760.116730
# 6411                                         274.632071
# 6439                                         189.611543
# 6467                                         196.849490
#
#       Deaths - Diet high in red meat - Sex: Both - Age: All Ages (Number)  \
# 27                                         9.994555e-04
# 55                                         2.710364e+00
# 83                                         8.200700e-03
# 111                                        3.212988e-01
# 139                                        5.867989e+01
# ...                                                 ...
# 6355                                       1.779343e+00
# 6383                                       2.483329e+04
# 6411                                       1.044604e-07
# 6439                                       1.473957e-07
# 6467                                       4.705305e-03
#
#       Deaths - Diet low in whole grains - Sex: Both - Age: All Ages (Number)  \
# 27                                         1.488496e+04
# 55                                         2.206717e+03
# 83                                         1.610308e+04
# 111                                        2.563875e+01
# 139                                        1.096710e+04
# ...                                                 ...
# 6355                                       6.201625e+04
# 6383                                       3.065589e+06
# 6411                                       1.244528e+04
# 6439                                       1.792215e+03
# 6467                                       2.664133e+03
#
#       Deaths - Diet low in nuts and seeds - Sex: Both - Age: All Ages (Number)  \
# 27                                         9.074388e+03
# 55                                         1.130544e+03
# 83                                         1.148331e+04
# 111                                        1.752416e+01
# 139                                        8.049420e+03
# ...                                                 ...
# 6355                                       3.404690e+04
# 6383                                       2.062522e+06
# 6411                                       8.677625e+03
# 6439                                       1.580105e+03
# 6467                                       2.449546e+03
#
#       Deaths - Diet low in seafood omega-3 fatty acids - Sex: Both - Age: All Ages (Number)
# 27                                         7.775130e+03
# 55                                         8.457940e+02
# 83                                         8.810311e+03
# 111                                        8.137023e+00
# 139                                        4.788967e+03
# ...                                                 ...
# 6355                                       2.969483e+04
# 6383                                       1.444907e+06
# 6411                                       6.783494e+03
# 6439                                       1.163538e+03
# 6467                                       1.762184e+03
#
# [231 rows x 38 columns]

# %%
#sum all deaths
cod_sum = cod_df.sum(axis=1)
cod_sum
# Out:
# 27      2.815395e+05
# 55      3.314386e+04
# 83      2.377406e+05
# 111     2.456121e+03
# 139     2.576397e+05
#             ...
# 6355    3.050567e+06
# 6383    6.687848e+07
# 6411    2.107088e+05
# 6439    1.055452e+05
# 6467    1.229190e+05
# Length: 231, dtype: float64

# %%
#add in sum column (https://www.geeksforgeeks.org/adding-new-column-to-existing-dataframe-in-pandas/)
cod_df['sum'] = cod_sum
cod_df.head()
# Out:
# <ipython-input-13-e82c2f813afb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cod_df['sum'] = cod_sum
#                    Entity Code  Year  \
# 27            Afghanistan  AFG  2017
# 55                Albania  ALB  2017
# 83                Algeria  DZA  2017
# 111        American Samoa  ASM  2017
# 139  Andean Latin America  NaN  2017
#
#      Deaths - Unsafe water source - Sex: Both - Age: All Ages (Number)  \
# 27                                         5256.649276
# 55                                            4.091664
# 83                                          189.936097
# 111                                           0.720056
# 139                                        1257.987062
#
#      Deaths - Unsafe sanitation - Sex: Both - Age: All Ages (Number)  \
# 27                                         3783.111117
# 55                                            1.597907
# 83                                           58.910622
# 111                                           0.179205
# 139                                         733.649228
#
#      Deaths - No access to handwashing facility - Sex: Both - Age: All Ages (Number)  \
# 27                                         4156.209013
# 55                                            4.501301
# 83                                          191.730462
# 111                                           0.293769
# 139                                        1578.129626
#
#      Deaths - Household air pollution from solid fuels - Sex: Both - Age: All Ages (Number)  \
# 27                                        19397.378213
# 55                                          736.881455
# 83                                           58.112360
# 111                                           7.550280
# 139                                        5773.892670
#
#      Deaths - Non-exclusive breastfeeding - Sex: Both - Age: All Ages (Number)  \
# 27                                         2422.369175
# 55                                            8.173119
# 83                                          126.552097
# 111                                           0.118482
# 139                                         344.102079
#
#      Deaths - Discontinued breastfeeding - Sex: Both - Age: All Ages (Number)  \
# 27                                           94.118135
# 55                                            0.071829
# 83                                            7.723609
# 111                                           0.003936
# 139                                          20.477721
#
#      Deaths - Child wasting - Sex: Both - Age: All Ages (Number)  ...  \
# 27                                        14575.269211            ...
# 55                                           40.613209            ...
# 83                                          635.454715            ...
# 111                                           2.285860            ...
# 139                                        3615.348894            ...
#
#      Deaths – Outdoor air pollution (all ages) (IHME)  \
# 27                                            6872.06
# 55                                             919.59
# 83                                           13315.30
# 111                                             14.63
# 139                                          12011.09
#
#      Deaths - Diet low in fiber - Sex: Both - Age: All Ages (Number)  \
# 27                                         4889.502247
# 55                                          428.785803
# 83                                         3004.104009
# 111                                           2.679124
# 139                                        3337.535571
#
#      Deaths - Diet high in sodium - Sex: Both - Age: All Ages (Number)  \
# 27                                         3457.083571
# 55                                         1668.336331
# 83                                         5828.759675
# 111                                           8.519993
# 139                                        9758.081534
#
#      Deaths - Diet low in legumes - Sex: Both - Age: All Ages (Number)  \
# 27                                         4384.887948
# 55                                          429.775831
# 83                                         2761.644707
# 111                                           4.836963
# 139                                        2169.986257
#
#      Deaths - Diet low in calcium - Sex: Both - Age: All Ages (Number)  \
# 27                                          325.722066
# 55                                           23.218640
# 83                                          370.146859
# 111                                           1.089152
# 139                                        1033.264841
#
#      Deaths - Diet high in red meat - Sex: Both - Age: All Ages (Number)  \
# 27                                            0.000999
# 55                                            2.710364
# 83                                            0.008201
# 111                                           0.321299
# 139                                          58.679893
#
#      Deaths - Diet low in whole grains - Sex: Both - Age: All Ages (Number)  \
# 27                                        14884.958403
# 55                                         2206.716542
# 83                                        16103.078982
# 111                                          25.638747
# 139                                       10967.097020
#
#      Deaths - Diet low in nuts and seeds - Sex: Both - Age: All Ages (Number)  \
# 27                                         9074.388004
# 55                                         1130.544001
# 83                                        11483.306530
# 111                                          17.524164
# 139                                        8049.419977
#
#      Deaths - Diet low in seafood omega-3 fatty acids - Sex: Both - Age: All Ages (Number)  \
# 27                                         7775.129667
# 55                                          845.793999
# 83                                         8810.310800
# 111                                           8.137023
# 139                                        4788.966632
#
#                sum
# 27   281539.488500
# 55    33143.859240
# 83   237740.565032
# 111    2456.120959
# 139  257639.739148
#
# [5 rows x 39 columns]

# %%
#select columns for analysis
cod_df = cod_df[['Entity', 'Code','Year', 'Deaths - Unsafe water source - Sex: Both - Age: All Ages (Number)', 'Deaths - Unsafe sanitation - Sex: Both - Age: All Ages (Number)', 'Deaths - No access to handwashing facility - Sex: Both - Age: All Ages (Number)', 'sum']]
cod_df.head()
# Out:
#                    Entity Code  Year  \
# 27            Afghanistan  AFG  2017
# 55                Albania  ALB  2017
# 83                Algeria  DZA  2017
# 111        American Samoa  ASM  2017
# 139  Andean Latin America  NaN  2017
#
#      Deaths - Unsafe water source - Sex: Both - Age: All Ages (Number)  \
# 27                                         5256.649276
# 55                                            4.091664
# 83                                          189.936097
# 111                                           0.720056
# 139                                        1257.987062
#
#      Deaths - Unsafe sanitation - Sex: Both - Age: All Ages (Number)  \
# 27                                         3783.111117
# 55                                            1.597907
# 83                                           58.910622
# 111                                           0.179205
# 139                                         733.649228
#
#      Deaths - No access to handwashing facility - Sex: Both - Age: All Ages (Number)  \
# 27                                         4156.209013
# 55                                            4.501301
# 83                                          191.730462
# 111                                           0.293769
# 139                                        1578.129626
#
#                sum
# 27   281539.488500
# 55    33143.859240
# 83   237740.565032
# 111    2456.120959
# 139  257639.739148

# %%
#rename columns 
cod_df = cod_df.rename(columns={'Deaths - Unsafe water source - Sex: Both - Age: All Ages (Number)': 'unsafe_water_source', 'Deaths - Unsafe sanitation - Sex: Both - Age: All Ages (Number)':'unsafe_sanitation', 'Deaths - No access to handwashing facility - Sex: Both - Age: All Ages (Number)':'no_access_handwashing'})
cod_df.head()
# Out:
#                    Entity Code  Year  unsafe_water_source  unsafe_sanitation  \
# 27            Afghanistan  AFG  2017          5256.649276        3783.111117
# 55                Albania  ALB  2017             4.091664           1.597907
# 83                Algeria  DZA  2017           189.936097          58.910622
# 111        American Samoa  ASM  2017             0.720056           0.179205
# 139  Andean Latin America  NaN  2017          1257.987062         733.649228
#
#      no_access_handwashing            sum
# 27             4156.209013  281539.488500
# 55                4.501301   33143.859240
# 83              191.730462  237740.565032
# 111               0.293769    2456.120959
# 139            1578.129626  257639.739148

# %%
cod_df = cod_df.dropna()
cod_df
# Out:
#               Entity      Code  Year  unsafe_water_source  unsafe_sanitation  \
# 27       Afghanistan       AFG  2017         5.256649e+03        3783.111117
# 55           Albania       ALB  2017         4.091664e+00           1.597907
# 83           Algeria       DZA  2017         1.899361e+02          58.910622
# 111   American Samoa       ASM  2017         7.200565e-01           0.179205
# 167          Andorra       AND  2017         2.702152e-02           0.018488
# ...              ...       ...   ...                  ...                ...
# 6271         Vietnam       VNM  2017         1.576620e+03         813.566332
# 6383           World  OWID_WRL  2017         1.232368e+06      774240.986150
# 6411           Yemen       YEM  2017         6.435590e+03        4011.286680
# 6439          Zambia       ZMB  2017         6.288668e+03        4718.900370
# 6467        Zimbabwe       ZWE  2017         3.796071e+03        2612.122560
#
#       no_access_handwashing           sum
# 27              4156.209013  2.815395e+05
# 55                 4.501301  3.314386e+04
# 83               191.730462  2.377406e+05
# 111                0.293769  2.456121e+03
# 167                0.206306  2.510520e+03
# ...                     ...           ...
# 6271            1730.772182  7.354276e+05
# 6383          707247.712854  6.687848e+07
# 6411            3029.543803  2.107088e+05
# 6439            4553.893978  1.055452e+05
# 6467            3579.352078  1.229190e+05
#
# [196 rows x 7 columns]

# %%
#convert strings to lower case for PG Admin connection
cod_df.columns = cod_df.columns.str.lower()
cod_df.head()
# Out:
#              entity code  year  unsafe_water_source  unsafe_sanitation  \
# 27      Afghanistan  AFG  2017          5256.649276        3783.111117
# 55          Albania  ALB  2017             4.091664           1.597907
# 83          Algeria  DZA  2017           189.936097          58.910622
# 111  American Samoa  ASM  2017             0.720056           0.179205
# 167         Andorra  AND  2017             0.027022           0.018488
#
#      no_access_handwashing            sum
# 27             4156.209013  281539.488500
# 55                4.501301   33143.859240
# 83              191.730462  237740.565032
# 111               0.293769    2456.120959
# 167               0.206306    2510.519621

# %%
#find percentage of deaths (https://stackoverflow.com/questions/36619631/how-to-divide-two-columns-element-wise-in-a-pandas-dataframe)
cod_df["unsafe_water_perct"] = (cod_df['unsafe_water_source']/cod_df['sum'])*100
cod_df["unsafe_sanitation_perct"] = (cod_df['unsafe_sanitation']/cod_df['sum'])*100
cod_df["no_handwashing_perct"] = (cod_df['no_access_handwashing']/cod_df['sum'])*100
cod_df.head()
# Out:
#              entity code  year  unsafe_water_source  unsafe_sanitation  \
# 27      Afghanistan  AFG  2017          5256.649276        3783.111117
# 55          Albania  ALB  2017             4.091664           1.597907
# 83          Algeria  DZA  2017           189.936097          58.910622
# 111  American Samoa  ASM  2017             0.720056           0.179205
# 167         Andorra  AND  2017             0.027022           0.018488
#
#      no_access_handwashing            sum  unsafe_water_perct  \
# 27             4156.209013  281539.488500            1.867109
# 55                4.501301   33143.859240            0.012345
# 83              191.730462  237740.565032            0.079892
# 111               0.293769    2456.120959            0.029317
# 167               0.206306    2510.519621            0.001076
#
#      unsafe_sanitation_perct  no_handwashing_perct
# 27                  1.343723              1.476244
# 55                  0.004821              0.013581
# 83                  0.024779              0.080647
# 111                 0.007296              0.011961
# 167                 0.000736              0.008218

# %%
#check data types (need to convert object to float)
cod_df.dtypes
# Out:
# entity                      object
# code                        object
# year                         int64
# unsafe_water_source        float64
# unsafe_sanitation          float64
# no_access_handwashing      float64
# sum                        float64
# unsafe_water_perct         float64
# unsafe_sanitation_perct    float64
# no_handwashing_perct       float64
# dtype: object

# %%
merge_df = pd.merge(cod_df, safe_water_df, on="code")
merge_df
# Out:
#             entity code  year  unsafe_water_source  unsafe_sanitation  \
# 0          Albania  ALB  2017             4.091664           1.597907
# 1   American Samoa  ASM  2017             0.720056           0.179205
# 2          Andorra  AND  2017             0.027022           0.018488
# 3          Armenia  ARM  2017             3.045523           4.379285
# 4          Austria  AUT  2017             2.407016           6.282778
# ..             ...  ...   ...                  ...                ...
# 95         Ukraine  UKR  2017            54.127601          41.273840
# 96  United Kingdom  GBR  2017            39.975723           6.198679
# 97   United States  USA  2017           296.744882         576.851003
# 98      Uzbekistan  UZB  2017           105.053926         120.096099
# 99         Vanuatu  VUT  2017            28.056882          20.948589
#
#     no_access_handwashing           sum  unsafe_water_perct  \
# 0                4.501301  3.314386e+04            0.012345
# 1                0.293769  2.456121e+03            0.029317
# 2                0.206306  2.510520e+03            0.001076
# 3               12.664885  4.578739e+04            0.006651
# 4                8.644877  9.225982e+04            0.002609
# ..                    ...           ...                 ...
# 95             181.319152  1.234861e+06            0.004383
# 96             252.575925  5.263808e+05            0.007594
# 97             795.287168  2.902411e+06            0.010224
# 98             296.505464  3.607610e+05            0.029120
# 99              16.391068  5.146171e+03            0.545199
#
#     unsafe_sanitation_perct  no_handwashing_perct    country_name  \
# 0                  0.004821              0.013581         Albania
# 1                  0.007296              0.011961  American Samoa
# 2                  0.000736              0.008218         Andorra
# 3                  0.009564              0.027660         Armenia
# 4                  0.006810              0.009370         Austria
# ..                      ...                   ...             ...
# 95                 0.003342              0.014683         Ukraine
# 96                 0.001178              0.047983  United Kingdom
# 97                 0.019875              0.027401   United States
# 98                 0.033290              0.082189      Uzbekistan
# 99                 0.407071              0.318510         Vanuatu
#
#     safe_water_2017
# 0         70.023150
# 1         12.575083
# 2         90.639997
# 3         86.476355
# 4         98.906201
# ..              ...
# 95        92.006857
# 96        99.988779
# 97        99.001778
# 98        58.903805
# 99        44.130326
#
# [100 rows x 12 columns]

# %%
# merge_df.to_csv(r'merge_df.csv', index = False)

# %%
merge_df.dtypes
# Out:
# entity                      object
# code                        object
# year                         int64
# unsafe_water_source        float64
# unsafe_sanitation          float64
# no_access_handwashing      float64
# sum                        float64
# unsafe_water_perct         float64
# unsafe_sanitation_perct    float64
# no_handwashing_perct       float64
# country_name                object
# safe_water_2017            float64
# dtype: object

# %%
# Creating our engine for PostGRES database
rds_connection_string = (f'postgres:{password}@localhost:5432/water_data_db')
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
meta = MetaData()
sanitation = Table(
   'sanitation', meta, 
   Column('entity', String), 
   Column('code', String, primary_key = True), 
   Column('year', Integer),
   Column('unsafe_water_source', Float),
   Column('unsafe_sanitation', Float),
   Column('no_access_handwashing', Float),
   Column('sum', Float),
   Column('unsafe_water_perct', Float),
   Column('unsafe_sanitation_perct', Float),
   Column('no_handwashing_perct', Float),
   Column('country_name', String),
   Column('safe_water_2017', Float) 
)
meta.create_all(engine)

# %%
#uploading the data to the SQL database sanitation
merge_df.to_sql(name='sanitation', con=engine, if_exists='append', index=False)
conn = engine.connect()

# %%
test= pd.read_sql("""select * from sanitation""", conn)

# %%
test.tail()
# Out:
#             entity code  year  unsafe_water_source  unsafe_sanitation  \
# 95         Ukraine  UKR  2017            54.127601          41.273840
# 96  United Kingdom  GBR  2017            39.975723           6.198679
# 97   United States  USA  2017           296.744882         576.851003
# 98      Uzbekistan  UZB  2017           105.053926         120.096099
# 99         Vanuatu  VUT  2017            28.056882          20.948589
#
#     no_access_handwashing           sum  unsafe_water_perct  \
# 95             181.319152  1.234861e+06            0.004383
# 96             252.575925  5.263808e+05            0.007594
# 97             795.287168  2.902411e+06            0.010224
# 98             296.505464  3.607610e+05            0.029120
# 99              16.391068  5.146171e+03            0.545199
#
#     unsafe_sanitation_perct  no_handwashing_perct    country_name  \
# 95                 0.003342              0.014683         Ukraine
# 96                 0.001178              0.047983  United Kingdom
# 97                 0.019875              0.027401   United States
# 98                 0.033290              0.082189      Uzbekistan
# 99                 0.407071              0.318510         Vanuatu
#
#     safe_water_2017
# 95        92.006857
# 96        99.988779
# 97        99.001778
# 98        58.903805
# 99        44.130326
